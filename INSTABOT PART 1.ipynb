# %%
from selenium import webdriver
driver =webdriver.Chrome(executable_path="D:\chromedriver_win32\chromedriver.exe")
driver.get('https://www.instagram.com/?hl=en')
driver.implicitly_wait(5)
login_username=driver.find_element_by_name("username")
login_password=driver.find_element_by_name('password')
login_username.send_keys('Sample Username')
login_password.send_keys('password')
login_password.submit()

# %%
food_list=driver.find_element_by_class_name("XTCLo")
food_list.send_keys('food')
food_name=driver.find_elements_by_class_name("Ap253")
for i in food_name:
    if i.get_attribute('innerHTML')[0]=='#':
        continue
    else:
        print(i.get_attribute('innerHTML'))
food_list.clear()
# Out:
# yourfoodlab
# dilsefoodie
# buzzfeedfood
# foodtalkindia
# foodconnectindia
# cravingtoeat
# food
# food_belly11
# ndtv_food
# foodlookingdigital
# foodie_incarnate
# food_lunatic
# foodnetwork
# food_affair
# foodbossindia
# foodiesince96
# foodinsider
# delhi_food_guide
# foodonyourplate
# delhifoodguide
# _food_o_feast_
# food_and_makeup_lover
# foodhallindia
# foodmaniacindia
# foodbloggerai
# vineefoodkorner
# food.darzee
# food_first_always
# foodiliciousmoments
# food_coma_usa
# food_gambler
# food_junc
# food.prn.share
# thewickedsoul
# karanfoodfanatic
# delhieater
# food_travel_etc
# foodiekaurexpeditions
# hmm_nikhil
# foodcrazymumbai
# dillifoodjunkie
# street_food_chandigarh
# delhifoodie
# gourmetmusafir
# bestfoodofindia
# foodcastle_by_devika
# foodisnirvana
# odia_food
# _foodpaths_
# indian_food_freak
# food_maple05
# foodieveggie
# foodelhi
# palateofdelhi

# %%
food_list=driver.find_element_by_class_name("XTCLo")
food_list.send_keys('So Delhi')
driver.implicitly_wait(5)
#following so delhi instagram handle
driver.find_element_by_class_name("z556c").click()
driver.find_element_by_class_name("_5f5mN").click()
print('START FOLLOWING')
#UNFOLLOWING THE INSTAGRAM HANDLE
#driver.find_element_by_class_name("_5f5mN").click()
driver.find_element_by_class_name("aOOlW").click()
print('UNFOLLOWED SO DELHI')
# Out:
# START FOLLOWING
# UNFOLLOWED SO DELHI

# %%
food_list=driver.find_element_by_class_name("XTCLo")
food_list.send_keys('dilsefoodie')
driver.find_element_by_class_name("Ap253").click()
driver.implicitly_wait(4)
driver.find_element_by_class_name("_9AhH0").click()

# %%
import time
for i in range(30):
    driver.find_element_by_class_name("fr66n").click()
    time.sleep(2)
    driver.find_element_by_class_name("_65Bje").click()
    time.sleep(2)

# %%
import time
for i in range(30):
    driver.find_element_by_class_name("ITLxV").click()
    time.sleep(2)
    driver.find_element_by_class_name("fr66n").click()
    time.sleep(2)
driver.find_element_by_class_name("Igw0E.IwRSH.eGOV_._4EzTm.BI4qX.qJPeX.fm1AK.TxciK.yiMZG").click()

# %%
food_list=driver.find_element_by_class_name("XTCLo")
food_list.send_keys('foodtalkindia')
driver.find_element_by_class_name("z556c").click()

# %%
import time
a=driver.find_elements_by_class_name("g47SY")
a[1].click()
f  = driver.find_element_by_xpath("//div[@class='isgrP']")
followers_2 = []
scroll = 0
while scroll < 15:
    follower = driver.find_elements_by_xpath("//*[contains(@class, 'd7ByH')]")
    for i in follower:
        followers_2.append(i.text)
    driver.execute_script('arguments[0].scrollTop = arguments[0].scrollTop + arguments[0].offsetHeight;', f)
    time.sleep(2)
    scroll += 1
cross_sign=driver.find_elements_by_class_name("WaOAr")
cross_sign[1].click()
for i in range(1,501):
    print(i,'.',followers_2[i])
# Out:
# 1 . surbhi0984
# 2 . chef.channel
# 3 . paramveersinghhanspal
# 4 . raksha.digital
# 5 . rpawar420
# 6 . rajairconditioner
# 7 . milkywaychaser_
# 8 . sanina14
# 9 . _raiyan_0021_
# 10 . kakkar_anmol
# 11 . akshitas_food_blog
# 12 . kalrananki
# 13 . sonam.narang.779
# 14 . swatichande05
# 15 . my.own.world.15
# 16 . gnol_s
# 17 . sana.zafar.sz
# 18 . brando_just_do
# 19 . wandering_am
# 20 . prajwal8321
# 21 . md_arshu04
# 22 . liza_richards
# 23 . numan_khan_003
# 24 . aakashyadav_2004
# 25 . surbhi0984
# 26 . chef.channel
# 27 . paramveersinghhanspal
# 28 . raksha.digital
# 29 . rpawar420
# 30 . rajairconditioner
# 31 . milkywaychaser_
# 32 . sanina14
# 33 . _raiyan_0021_
# 34 . kakkar_anmol
# 35 . akshitas_food_blog
# 36 . kalrananki
# 37 . sonam.narang.779
# 38 . swatichande05
# 39 . my.own.world.15
# 40 . gnol_s
# 41 . sana.zafar.sz
# 42 . brando_just_do
# 43 . wandering_am
# 44 . prajwal8321
# 45 . md_arshu04
# 46 . liza_richards
# 47 . numan_khan_003
# 48 . aakashyadav_2004
# ...

# %%
from selenium.common.exceptions import ElementClickInterceptedException
search=driver.find_element_by_class_name("XTCLo")
search.send_keys('coding.ninjas')
driver.find_element_by_class_name("Ap253").click()
driver.implicitly_wait(4)
story=driver.find_element_by_class_name("_2dbep")
story.click()
print('story_seen')
# Out:
# story_seen
